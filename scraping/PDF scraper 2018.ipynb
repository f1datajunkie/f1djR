# %%
! mkdir -p  eventTiming/2019

# %%
import requests
from bs4 import BeautifulSoup

# %%
url='http://www.fia.com/events/fia-formula-one-world-championship/season-2019/formula-one'
response = requests.get(url,params={})

# %%
soup=BeautifulSoup(response.content, 'lxml')
events=soup.findAll('div',{'class':'event-item past'})

# %%
len(events)
# Out:
# 21

# %%
# !ls eventTiming/AUS/
# Out:
# Championship Points.pdf
# Circuit Map.pdf
# Entry List.pdf
# Friday Press Conference.pdf
# Grand Prix Preview.pdf
# Media Kit.pdf
# Note to Teams.pdf
# P1 - Classification.pdf
# P1 - Lap Times.pdf
# P2 - Classification.pdf
# P2 - Lap Times.pdf
# P3 - Classification.pdf
# P3 - Lap Times.pdf
# Post Qualifying Press Conference.pdf
# Post Race Press Conference.pdf
# Press Conference Schedule.pdf
# Q - Best Sector Times.pdf
# Q - Lap Times.pdf
# Q - Maximum Speeds.pdf
# Q - Official Classification.pdf
# Q - Provisional Classification.pdf
# R - Best Sector Times.pdf
# R - Fastest Laps.pdf
# R - History Chart.pdf
# R - Lap Analysis.pdf
# R - Lap Chart.pdf
# R - Maximum Speeds.pdf
# R - Official Classification.pdf
# R - Official Starting Grid.pdf
# R - Pit Stop Summary.pdf
# R - Provisional Classification.pdf
# R - Provisional Starting Grid.pdf
# Revised Event Notes.pdf
# Stewards Decision Doc10 - D. Ricciardo.pdf
# Stewards Decision Doc12 - Intermediate Tyres.pdf
# Stewards Decision Doc13 - SC2-SC1 Time.pdf
# Stewards Decision Doc15 - K. Raikkonen.pdf
# Stewards Decision Doc16 - D. Ricciardo.pdf
# Stewards Decision Doc25 - V.Bottas.pdf
# Stewards Decision Doc31 - K.Magnussen.pdf
# Stewards Decision Doc32 - R.Grosjean.pdf
# Stewards Decision Doc5 - P.Gasly.pdf
# Stewards Decision Doc6 - B.Hartley.pdf
# Stewards Decision Doc8 - K.Raikkonen.pdf
# Stewards Decision Doc9 - V.Bottas.pdf
# Summons Doc28 - Haas F1 Team.pdf
# Summons Doc29 - Haas F1 Team.pdf
# T. Mayer, E. Spano, E. Pirro.pdf
# Technical Report Doc14 - FP1_FP2.pdf
# Technical Report Doc20 - Dry Tyre Type.pdf
# Technical Report Doc21 - FP3_Qualifying.pdf
# Technical Report Doc24 - Parc Ferm Issues.pdf
# Technical Report Doc24 - Parc Fermé Issues (Unicode Encoding Conflict).pdf
# Technical Report Doc24 - Parc Fermé Issues.pdf
# Technical Report Doc26 - Parc Ferm.pdf
# Technical Report Doc26 - Parc Fermé (Unicode Encoding Conflict).pdf
# Technical Report Doc26 - Parc Fermé.pdf
# Technical Report Doc3 - Initial Scrutineering.pdf
# Technical Report Doc33 - Race Scrutineering.pdf
# Thursday Press Conference.pdf

# %%
events
# Out:
# [<div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">25</div>
#  <div class="month">Mar</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/australian-grand-prix"><div class="event-name cell">Australian Grand Prix</div>
#  <div class="event-location">ALBERT PARK</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="AU" class="countryicon iconset-gosquared_flat_large countrycode-au" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/au.png" title=""/> <div class="country-name">AUS</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">08</div>
#  <div class="month">Apr</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/bahrain-grand-prix"><div class="event-name cell">Bahrain Grand Prix</div>
#  <div class="event-location">BAHRAIN</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-0">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="BH" class="countryicon iconset-gosquared_flat_large countrycode-bh" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/bh.png" title=""/> <div class="country-name">BHR</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">15</div>
#  <div class="month">Apr</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/chinese-grand-prix"><div class="event-name cell">Chinese Grand Prix</div>
#  <div class="event-location">SHANGHAI INTERNATIONAL</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-1">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="CN" class="countryicon iconset-gosquared_flat_large countrycode-cn" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/cn.png" title=""/> <div class="country-name">CHN</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">29</div>
#  <div class="month">Apr</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/azerbaijan-grand-prix"><div class="event-name cell">Azerbaijan Grand Prix</div>
#  <div class="event-location">BAKU</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="https://www.fia.com/events/fia-formula-one-world-championship/season-2018/race-classification-27">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="AZ" class="countryicon iconset-gosquared_flat_large countrycode-az" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/az.png" title=""/> <div class="country-name">AZE</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">13</div>
#  <div class="month">May</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/spanish-grand-prix"><div class="event-name cell">Spanish Grand Prix</div>
#  <div class="event-location">CATALUNYA</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-3">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="ES" class="countryicon iconset-gosquared_flat_large countrycode-es" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/es.png" title=""/> <div class="country-name">ESP</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">27</div>
#  <div class="month">May</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/monaco-grand-prix"><div class="event-name cell">Monaco Grand Prix</div>
#  <div class="event-location">MONACO</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-23">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="MC" class="countryicon iconset-gosquared_flat_large countrycode-mc" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/mc.png" title=""/> <div class="country-name">MCO</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">10</div>
#  <div class="month">Jun</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/canadian-grand-prix"><div class="event-name cell">Canadian Grand Prix</div>
#  <div class="event-location">Montréal Gilles Villeneuve</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-5">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="CA" class="countryicon iconset-gosquared_flat_large countrycode-ca" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/ca.png" title=""/> <div class="country-name">CAN</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">24</div>
#  <div class="month">Jun</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/french-grand-prix"><div class="event-name cell">French Grand Prix</div>
#  <div class="event-location">PAUL RICARD</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-6">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="FR" class="countryicon iconset-gosquared_flat_large countrycode-fr" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/fr.png" title=""/> <div class="country-name">FRA</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">01</div>
#  <div class="month">Jul</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/austrian-grand-prix"><div class="event-name cell">Austrian Grand Prix</div>
#  <div class="event-location">RED BULL RING - SPIELBERG</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-7">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="AT" class="countryicon iconset-gosquared_flat_large countrycode-at" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/at.png" title=""/> <div class="country-name">AUT</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">08</div>
#  <div class="month">Jul</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/british-grand-prix"><div class="event-name cell">British Grand Prix</div>
#  <div class="event-location">SILVERSTONE GRAND PRIX</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-8">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="GB" class="countryicon iconset-gosquared_flat_large countrycode-gb" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/gb.png" title=""/> <div class="country-name">GBR</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">22</div>
#  <div class="month">Jul</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/german-grand-prix"><div class="event-name cell">German Grand Prix</div>
#  <div class="event-location">HOCKENHEIM GRAND PRIX</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-26">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="DE" class="countryicon iconset-gosquared_flat_large countrycode-de" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/de.png" title=""/> <div class="country-name">DEU</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">29</div>
#  <div class="month">Jul</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/hungarian-grand-prix"><div class="event-name cell">Hungarian Grand Prix</div>
#  <div class="event-location">HUNGARORING</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-28">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="HU" class="countryicon iconset-gosquared_flat_large countrycode-hu" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/hu.png" title=""/> <div class="country-name">HUN</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">26</div>
#  <div class="month">Aug</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/belgian-grand-prix"><div class="event-name cell">Belgian Grand Prix</div>
#  <div class="event-location">SPA-FRANCORCHAMPS</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-29">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="BE" class="countryicon iconset-gosquared_flat_large countrycode-be" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/be.png" title=""/> <div class="country-name">BEL</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">02</div>
#  <div class="month">Sep</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/italian-grand-prix"><div class="event-name cell">Italian Grand Prix</div>
#  <div class="event-location">MONZA</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-30">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="IT" class="countryicon iconset-gosquared_flat_large countrycode-it" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/it.png" title=""/> <div class="country-name">ITA</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">16</div>
#  <div class="month">Sep</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/singapore-grand-prix"><div class="event-name cell">Singapore Grand Prix</div>
#  <div class="event-location">SINGAPORE - MARINA BAY</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-13">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="SG" class="countryicon iconset-gosquared_flat_large countrycode-sg" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/sg.png" title=""/> <div class="country-name">SGP</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">30</div>
#  <div class="month">Sep</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/russian-grand-prix"><div class="event-name cell">Russian Grand Prix</div>
#  <div class="event-location">SOCHI</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-31">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="RU" class="countryicon iconset-gosquared_flat_large countrycode-ru" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/ru.png" title=""/> <div class="country-name">RUS</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">07</div>
#  <div class="month">Oct</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/japanese-grand-prix"><div class="event-name cell">Japanese Grand Prix</div>
#  <div class="event-location">SUZUKA</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-32">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="JP" class="countryicon iconset-gosquared_flat_large countrycode-jp" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/jp.png" title=""/> <div class="country-name">JPN</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">21</div>
#  <div class="month">Oct</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/united-states-grand-prix"><div class="event-name cell">United States Grand Prix</div>
#  <div class="event-location">AUSTIN</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-25">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="US" class="countryicon iconset-gosquared_flat_large countrycode-us" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/us.png" title=""/> <div class="country-name">USA</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">28</div>
#  <div class="month">Oct</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/mexican-grand-prix"><div class="event-name cell">Mexican Grand Prix</div>
#  <div class="event-location">Hermanos Rodriguez</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-17">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="MX" class="countryicon iconset-gosquared_flat_large countrycode-mx" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/mx.png" title=""/> <div class="country-name">MEX</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">11</div>
#  <div class="month">Nov</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/brazilian-grand-prix"><div class="event-name cell">Brazilian Grand Prix</div>
#  <div class="event-location">INTERLAGOS</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-18">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="BR" class="countryicon iconset-gosquared_flat_large countrycode-br" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/br.png" title=""/> <div class="country-name">BRA</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">25</div>
#  <div class="month">Nov</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/abu-dhabi-grand-prix"><div class="event-name cell">Abu Dhabi Grand Prix</div>
#  <div class="event-location">ABU DHABI - YAS MARINA</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-20">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="AE" class="countryicon iconset-gosquared_flat_large countrycode-ae" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/ae.png" title=""/> <div class="country-name">ARE</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>]

# %%
events
# Out:
# [<div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">25</div>
#  <div class="month">Mar</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/australian-grand-prix"><div class="event-name cell">Australian Grand Prix</div>
#  <div class="event-location">ALBERT PARK</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="AU" class="countryicon iconset-gosquared_flat_large countrycode-au" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/au.png" title=""/> <div class="country-name">AUS</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">08</div>
#  <div class="month">Apr</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/bahrain-grand-prix"><div class="event-name cell">Bahrain Grand Prix</div>
#  <div class="event-location">BAHRAIN</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-0">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="BH" class="countryicon iconset-gosquared_flat_large countrycode-bh" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/bh.png" title=""/> <div class="country-name">BHR</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">15</div>
#  <div class="month">Apr</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/chinese-grand-prix"><div class="event-name cell">Chinese Grand Prix</div>
#  <div class="event-location">SHANGHAI INTERNATIONAL</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-1">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="CN" class="countryicon iconset-gosquared_flat_large countrycode-cn" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/cn.png" title=""/> <div class="country-name">CHN</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">29</div>
#  <div class="month">Apr</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/azerbaijan-grand-prix"><div class="event-name cell">Azerbaijan Grand Prix</div>
#  <div class="event-location">BAKU</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="https://www.fia.com/events/fia-formula-one-world-championship/season-2018/race-classification-27">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="AZ" class="countryicon iconset-gosquared_flat_large countrycode-az" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/az.png" title=""/> <div class="country-name">AZE</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">13</div>
#  <div class="month">May</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/spanish-grand-prix"><div class="event-name cell">Spanish Grand Prix</div>
#  <div class="event-location">CATALUNYA</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-3">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="ES" class="countryicon iconset-gosquared_flat_large countrycode-es" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/es.png" title=""/> <div class="country-name">ESP</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">27</div>
#  <div class="month">May</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/monaco-grand-prix"><div class="event-name cell">Monaco Grand Prix</div>
#  <div class="event-location">MONACO</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-23">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="MC" class="countryicon iconset-gosquared_flat_large countrycode-mc" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/mc.png" title=""/> <div class="country-name">MCO</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">10</div>
#  <div class="month">Jun</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/canadian-grand-prix"><div class="event-name cell">Canadian Grand Prix</div>
#  <div class="event-location">Montréal Gilles Villeneuve</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-5">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="CA" class="countryicon iconset-gosquared_flat_large countrycode-ca" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/ca.png" title=""/> <div class="country-name">CAN</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">24</div>
#  <div class="month">Jun</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/french-grand-prix"><div class="event-name cell">French Grand Prix</div>
#  <div class="event-location">PAUL RICARD</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-6">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="FR" class="countryicon iconset-gosquared_flat_large countrycode-fr" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/fr.png" title=""/> <div class="country-name">FRA</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">01</div>
#  <div class="month">Jul</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/austrian-grand-prix"><div class="event-name cell">Austrian Grand Prix</div>
#  <div class="event-location">RED BULL RING - SPIELBERG</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-7">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="AT" class="countryicon iconset-gosquared_flat_large countrycode-at" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/at.png" title=""/> <div class="country-name">AUT</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">08</div>
#  <div class="month">Jul</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/british-grand-prix"><div class="event-name cell">British Grand Prix</div>
#  <div class="event-location">SILVERSTONE GRAND PRIX</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-8">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="GB" class="countryicon iconset-gosquared_flat_large countrycode-gb" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/gb.png" title=""/> <div class="country-name">GBR</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">22</div>
#  <div class="month">Jul</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/german-grand-prix"><div class="event-name cell">German Grand Prix</div>
#  <div class="event-location">HOCKENHEIM GRAND PRIX</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-26">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="DE" class="countryicon iconset-gosquared_flat_large countrycode-de" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/de.png" title=""/> <div class="country-name">DEU</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">29</div>
#  <div class="month">Jul</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/hungarian-grand-prix"><div class="event-name cell">Hungarian Grand Prix</div>
#  <div class="event-location">HUNGARORING</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-28">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="HU" class="countryicon iconset-gosquared_flat_large countrycode-hu" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/hu.png" title=""/> <div class="country-name">HUN</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">26</div>
#  <div class="month">Aug</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/belgian-grand-prix"><div class="event-name cell">Belgian Grand Prix</div>
#  <div class="event-location">SPA-FRANCORCHAMPS</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-29">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="BE" class="countryicon iconset-gosquared_flat_large countrycode-be" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/be.png" title=""/> <div class="country-name">BEL</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">02</div>
#  <div class="month">Sep</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/italian-grand-prix"><div class="event-name cell">Italian Grand Prix</div>
#  <div class="event-location">MONZA</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-30">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="IT" class="countryicon iconset-gosquared_flat_large countrycode-it" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/it.png" title=""/> <div class="country-name">ITA</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">16</div>
#  <div class="month">Sep</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/singapore-grand-prix"><div class="event-name cell">Singapore Grand Prix</div>
#  <div class="event-location">SINGAPORE - MARINA BAY</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-13">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="SG" class="countryicon iconset-gosquared_flat_large countrycode-sg" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/sg.png" title=""/> <div class="country-name">SGP</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">30</div>
#  <div class="month">Sep</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/russian-grand-prix"><div class="event-name cell">Russian Grand Prix</div>
#  <div class="event-location">SOCHI</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-31">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="RU" class="countryicon iconset-gosquared_flat_large countrycode-ru" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/ru.png" title=""/> <div class="country-name">RUS</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">07</div>
#  <div class="month">Oct</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/japanese-grand-prix"><div class="event-name cell">Japanese Grand Prix</div>
#  <div class="event-location">SUZUKA</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-32">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="JP" class="countryicon iconset-gosquared_flat_large countrycode-jp" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/jp.png" title=""/> <div class="country-name">JPN</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">21</div>
#  <div class="month">Oct</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/united-states-grand-prix"><div class="event-name cell">United States Grand Prix</div>
#  <div class="event-location">AUSTIN</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-25">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="US" class="countryicon iconset-gosquared_flat_large countrycode-us" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/us.png" title=""/> <div class="country-name">USA</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">28</div>
#  <div class="month">Oct</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/mexican-grand-prix"><div class="event-name cell">Mexican Grand Prix</div>
#  <div class="event-location">Hermanos Rodriguez</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-17">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="MX" class="countryicon iconset-gosquared_flat_large countrycode-mx" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/mx.png" title=""/> <div class="country-name">MEX</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">11</div>
#  <div class="month">Nov</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/brazilian-grand-prix"><div class="event-name cell">Brazilian Grand Prix</div>
#  <div class="event-location">INTERLAGOS</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-18">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="BR" class="countryicon iconset-gosquared_flat_large countrycode-br" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/br.png" title=""/> <div class="country-name">BRA</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">25</div>
#  <div class="month">Nov</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2018/abu-dhabi-grand-prix"><div class="event-name cell">Abu Dhabi Grand Prix</div>
#  <div class="event-location">ABU DHABI - YAS MARINA</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2018/race-classification-20">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="AE" class="countryicon iconset-gosquared_flat_large countrycode-ae" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/ae.png" title=""/> <div class="country-name">ARE</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>]

# %%
timing=[x.lower() for x in ['Official Classification','Provisional Classification','Preliminary Classification',
        'Fastest Laps','History Chart','Lap Chart','Lap Analysis','Pit Stop Summary','Best Sector Times'
        ,'Maximum Speeds','Official Starting Grid','Provisional Starting Grid','Qualifying Session',
        'Official Classification','Provisional Classification','Speed Trap',
        'Preliminary Classification','Lap Times','Provisionnal Classification','Provisionnal Starting Grid',
        'Speed Trap','Classification',"Final Classification"]]

# %%
events
# Out:
# [<div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">17</div>
#  <div class="month">Mar</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2019/australian-grand-prix"><div class="event-name cell">Australian Grand Prix</div>
#  <div class="event-location">ALBERT PARK</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2019/race-classification-0">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="AU" class="countryicon iconset-gosquared_flat_large countrycode-au" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/au.png" title=""/> <div class="country-name">AUS</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">31</div>
#  <div class="month">Mar</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2019/bahrain-grand-prix"><div class="event-name cell">Bahrain Grand Prix</div>
#  <div class="event-location">BAHRAIN</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2019/race-classification-2">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="BH" class="countryicon iconset-gosquared_flat_large countrycode-bh" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/bh.png" title=""/> <div class="country-name">BHR</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>, <div class="event-item past">
#  <div class="inner">
#  <div class="date cell"> <div class="date-inner">
#  <div class="from-date cell">
#  <div class="day">14</div>
#  <div class="month">Apr</div>
#  </div>
#  </div> </div>
#  <div class="event cell"> <a href="/championship/events/fia-formula-one-world-championship/season-2019/chinese-grand-prix"><div class="event-name cell">Chinese Grand Prix</div>
#  <div class="event-location">SHANGHAI INTERNATIONAL</div></a> </div>
#  <div class="event-right-wrapper car-category-empty">
#  <div>
#  <div class="classification cell ">
#  <div class="classification-link">
#  <a class="link-label" href="/events/fia-formula-one-world-championship/season-2019/race-classification-6">Classification</a> </div>
#  </div>
#  <div class="car-category empty">
#  </div>
#  <div class="country cell">
#  <img alt="CN" class="countryicon iconset-gosquared_flat_large countrycode-cn" src="https://www.fia.com/sites/all/modules/contrib/countryicons_gosquared/flat-large/cn.png" title=""/> <div class="country-name">CHN</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>]

# %%
timing
# Out:
# ['official classification',
#  'provisional classification',
#  'preliminary classification',
#  'fastest laps',
#  'history chart',
#  'lap chart',
#  'lap analysis',
#  'pit stop summary',
#  'best sector times',
#  'maximum speeds',
#  'official starting grid',
#  'provisional starting grid',
#  'qualifying session',
#  'official classification',
#  'provisional classification',
#  'speed trap',
#  'preliminary classification',
#  'lap times',
#  'provisionnal classification',
#  'provisionnal starting grid',
#  'speed trap',
#  'classification']

# %%
import os
domain="http://www.fia.com"

import re

def download_file(url,f):
    response = re.urlopen(url)
    file = open("document.pdf", 'w')
    file.write(response.read())
    file.close()
    print("Completed")

for event in events:
    prev=''
    phase='R'
    gp=event.find('div',{'class':'event-name'}).text.replace('Grand Prix of ','').strip()
    c=event.find('div',{'class':'country-name'}).text.strip()
    l=event.find('div',{'class':'event-location'}).text.strip()
    u=event.find('div',{'class':'event cell'}).find('a')['href']
    
    print(gp,c,l)
    d='eventTiming/2019/{}'.format(c)
    if not os.path.exists(d):
        os.makedirs(d) 
    url='{}{}'.format(domain,u)
    print(url)
    eventpage=requests.get(url)
    eventsoup=BeautifulSoup(eventpage.content,'lxml')
    #print(eventsoup.find('a',text='Event & Timing information')['href'])
    #pdfsoup=BeautifulSoup(requests.get('{}{}'.format(domain,eventsoup.find('a',text='Event & Timing information')['href'])).content)
    #soup.findAll('a', href=re.compile('^http://www.nhl.com/ice/boxscore.htm\?id='))
    eventSlug='.*eventtiming-.*'
    print(eventsoup.find('a',href=re.compile(eventSlug))['href'])
    pdfsoup=BeautifulSoup(requests.get('{}{}'.format(domain,eventsoup.find('a',href=re.compile(eventSlug))['href'])).content,'lxml')
    middle=pdfsoup.find('div',{'class':'content'}).find('div',{'class':'middle'})

    for maybe in middle.findAll("a"):
        #print(maybe['href'])
        prepath=maybe.text.strip()#encode('ascii', 'ignore').strip()
        #print('fing path*{}*'.format(prepath))
        if prepath.lower() in timing:
            if (prev=='Official Starting Grid' and prepath=='Lap Times'): phase='P3'
            path='{} - {}'.format(phase,prepath)
            if prepath=='Provisional Starting Grid' or prepath=='Provisionnal Starting Grid':
                phase='Q'
            elif (phase=='Q' and prepath=='Maximum Speeds') or (phase=='Q' and (c=='MYS' or c=='CHN') and prepath=='Provisionnal Classification'):
                phase='P3'
            elif phase=='P3' and prepath=='Classification' :
                phase='P2'
            elif phase=='P2' and prepath=='Classification':
                phase='P1'
            #path='{} - {}'.format(phase,prepath)
        else:
            path=prepath
        prev=prepath
        p='{d}/{path}.pdf'.format(d=d,path=path.replace('/','_'))

        #print(p)
        if not os.path.isfile(p):
            print("downloading",d,maybe.text.encode('ascii', 'ignore'))
            os.system('wget {url} -O "{p}"'.format(url='{}{}'.format(domain,maybe['href']),p=p))
# Out:
# Australian Grand Prix AUS ALBERT PARK
# http://www.fia.com/championship/events/fia-formula-one-world-championship/season-2019/australian-grand-prix
# /events/fia-formula-one-world-championship/season-2019/eventtiming-information-1
# downloading eventTiming/2019/AUS b'Entry List'
# downloading eventTiming/2019/AUS b'Circuit map'
# downloading eventTiming/2019/AUS b'Final Classification '
# downloading eventTiming/2019/AUS b'Provisional Classification'
# downloading eventTiming/2019/AUS b'Fastest Laps'
# downloading eventTiming/2019/AUS b'History Chart'
# downloading eventTiming/2019/AUS b'Lap Chart'
# downloading eventTiming/2019/BHR b'Lap Chart'
# downloading eventTiming/2019/BHR b'Lap Analysis'
# downloading eventTiming/2019/BHR b'Pit Stop Summary'
# downloading eventTiming/2019/BHR b'Best Sector Times'
# downloading eventTiming/2019/BHR b'Maximum Speeds'
# downloading eventTiming/2019/BHR b'Final Starting Grid'
# downloading eventTiming/2019/BHR b'Provisional Starting Grid'
# downloading eventTiming/2019/BHR b'Official Classification'
# downloading eventTiming/2019/BHR b'Provisional Classification'
# downloading eventTiming/2019/BHR b'Lap Times'
# downloading eventTiming/2019/BHR b'Best Sector Times'
# downloading eventTiming/2019/BHR b'Maximum Speeds'
# downloading eventTiming/2019/BHR b'Lap Times'
# downloading eventTiming/2019/BHR b'Classification'
# downloading eventTiming/2019/BHR b'Lap Times'
# downloading eventTiming/2019/BHR b'Classification'
# downloading eventTiming/2019/BHR b'Lap Times'
# downloading eventTiming/2019/BHR b'Classification'
# downloading eventTiming/2019/BHR b'Technical Report Doc41 - Race Scrutineering'
# downloading eventTiming/2019/BHR b'Technical Report Doc31 - Parts & Parameters replaced or changed during the Parc Ferm '
# downloading eventTiming/2019/BHR b'Technical Report Doc28 - P3 & Qualifying Scrutineering'
# downloading eventTiming/2019/BHR b'Technical Report Doc25 - Dry tyre type used during fastest lap in Q2'
# downloading eventTiming/2019/BHR b'Technical Report Doc15 - New Gearboxes for this event  '
# downloading eventTiming/2019/BHR b'Technical Report Doc14 - P1 & P2 Scrutineering'
# downloading eventTiming/2019/BHR b'Technical Report Doc7 - New PU elements for this Event'
# downloading eventTiming/2019/BHR b'Technical Report Doc5 - Initial Scrutineering'
# downloading eventTiming/2019/BHR b'Technical Report Doc3 - PU elements used per driver up to now'
# downloading eventTiming/2019/BHR b'Technical Report Doc4 - PU elements used per driver up to now'
# downloading eventTiming/2019/BHR b'Stewards Decision Doc40 - D.Ricciardo'
# downloading eventTiming/2019/BHR b'Summons Doc38 - D.Ricciardo'
# downloading eventTiming/2019/BHR b'Stewards Decision Doc37 - D.Kvyat'
# downloading eventTiming/2019/BHR b'Stewards Decision Doc36 - A.Giovinazzi '
# downloading eventTiming/2019/BHR b'Offence Doc35 - D.Kvyat'
# downloading eventTiming/2019/BHR b'Stewards Decision Doc34 - M.Verstappen'
# downloading eventTiming/2019/BHR b'Stewards Decision Doc33 - C.Sainz'
# downloading eventTiming/2019/BHR b'Stewards Decision Doc27 - S.Vettel'
# downloading eventTiming/2019/BHR b'Summons Doc24 - S.Vettel '
# downloading eventTiming/2019/BHR b'Offence Doc23 - R.Grosjean'
# downloading eventTiming/2019/BHR b'Summons Doc21- L.Norris'
# downloading eventTiming/2019/BHR b'Summons Doc20 - R.Grosjean'
# downloading eventTiming/2019/BHR b'Stewards Decision Doc12 - N.Hlkenberg '
# downloading eventTiming/2019/BHR b'Summons Doc9 - N.Hlkenberg'
# downloading eventTiming/2019/BHR b'Summons Doc8 - A.Giovinazzi'
# downloading eventTiming/2019/BHR b'Press Conference Schedule'
# downloading eventTiming/2019/BHR b"Race Director's Note Event Note (Version 2)"
# downloading eventTiming/2019/BHR b"Race Director's Note - Post Qualifying Interviews"
# downloading eventTiming/2019/BHR b"Race Director's Note - P3 Tyres"
# downloading eventTiming/2019/BHR b"Race Director's Note - SC1/SC2"
# downloading eventTiming/2019/BHR b"Race Director's Event Note Doc2"
# downloading eventTiming/2019/BHR b'Thursday Press Conference'
